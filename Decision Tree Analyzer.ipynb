# %%
# %matplotlib inline
import pandas as pd

# %% [markdown]
# # Purpose

# %%
# Identify groups of observations that are different than others, then generate a list of these groups with their characteristics

# %%
def decision_tree(X,y,max_depth,min_samples_leaf):

    import numpy as np

    from sklearn.tree import DecisionTreeClassifier

    from sklearn.tree import DecisionTreeRegressor

    import pandas as pd

#     X=pd.get_dummies(X)

 

# Make a decision tree (classifier or regression)

    if y.dtype.name in ('float32','float64'):

        estimator = DecisionTreeRegressor(max_depth =max_depth,min_samples_leaf=min_samples_leaf)

    else:

        estimator = DecisionTreeClassifier(max_depth =max_depth,min_samples_leaf=min_samples_leaf)

    estimator.fit(X,y)

    return estimator

def leaf_aggregates(y,leave_id):

    import pandas as pd

    import numpy as np

    leaves_y=pd.DataFrame({'y': y ,'leaf_id':leave_id,'count':1})

    leaf_df =leaves_y.groupby("leaf_id").agg({"y": "mean","count":"count"})

    comparison_y= np.average(y)

    leaf_df["divergence"]=np.abs(leaf_df["y"]-comparison_y)

    leaf_df.reset_index(inplace=True)

    leaf_df = leaf_df.sort_values(by=['divergence'],ascending=False)

    return leaf_df

    leaf_df.plot.scatter("count","divergence")

def get_rules(estimator,X,target_id,leave_id):

    import pandas as pd

    # A matrix with an indicator for sample i whether node j is in its path

    node_indicator = estimator.decision_path(X)

    # Find the first sample that is in that leaf

    for i in range(len(X)):

        if node_indicator[i,target_id]==1:

            sample_id=i

            break

    # feature and threshold for every node

    feature = estimator.tree_.feature

    threshold = estimator.tree_.threshold

 

    # All of the nodes leading to the leaf

    node_index = node_indicator.indices[node_indicator.indptr[sample_id]:

                                        node_indicator.indptr[sample_id + 1]]

    # dataframe of rules

    rules = pd.DataFrame(columns = ['node_id','feature','sign','threshold'])

    for node_id in node_index:

        if leave_id[sample_id] == node_id:

            continue

        if (X.iloc[sample_id, feature[node_id]] <= threshold[node_id]):

            threshold_sign = "<="

        else:

            threshold_sign = ">"

 

        rules = rules.append({'node_id':node_id,'feature':X.columns[feature      [node_id]],'sign':threshold_sign,'threshold':threshold[node_id]}, ignore_index=True)   

    # organize rules

#     rules =rules[rules.sign=='>'].groupby(["feature","sign"]).agg({"threshold":"max"}).append(rules[rules.sign=='<='].groupby(["feature","sign"]).agg({"threshold":"min"}) ).reset_index().sort_values("feature")

    return rules

# for a given depth, returns all of the leaves

def decision_tree_analyzer(X,y,max_depth=5,min_samples_leaf = 1000):

    estimator = decision_tree(X,y,max_depth,min_samples_leaf)

    leave_id = estimator.apply(X)

    leaf_df = leaf_aggregates(y,leave_id)

    target_id = int(leaf_df.loc[leaf_df["divergence"].idxmax()].leaf_id)

    for target_id in leaf_df.leaf_id:

        rules = get_rules(estimator,X,target_id,leave_id)

        print(leaf_df[leaf_df.leaf_id==target_id])

        print(rules)

        print('')

 

# gives the most divergent leaf for every tree from depth 1 to 'deepest'       

def decision_tree_analyzer2(X,y,deepest=5,min_samples_leaf = 1000):

    for max_depth in range(1,deepest):

        estimator = decision_tree(X,y,max_depth,min_samples_leaf)

        leave_id = estimator.apply(X)

        leaf_df = leaf_aggregates(y,leave_id)

        target_id = int(leaf_df.loc[leaf_df["divergence"].idxmax()].leaf_id)

        rules = get_rules(estimator,X,target_id,leave_id)

        print(leaf_df[leaf_df.leaf_id==target_id])

        print(rules)

        print('')

        
def divergence_table(data,y_column,count_column,min_count=1000):

    import numpy as np
    avg_y=np.mean(data[y_column])

    big_var_table=pd.DataFrame(columns=[y_column, count_column, 'divergence', 'value',

           'variable'])

    for col in data.columns.drop(y_column):

        var_table = data.groupby(col).agg({y_column:"mean",count_column:"count"})

        var_table["divergence"]=np.abs(var_table[y_column]-avg_y)

        var_table=var_table[var_table[count_column]>min_count]

        var_table["value"]=var_table.index

        var_table = var_table.reset_index(drop=True)

        var_table = var_table.sort_values(by=['divergence'],ascending=False)

        var_table["variable"]=col

    #     var_table=var_table.rename(index=str, columns={col: "value"})

        big_var_table=big_var_table.append(var_table,ignore_index=True)

    return big_var_table.sort_values(by=['divergence'],ascending=False)

#todo: output the graph of leaves: count vs average
#todo: use out of sample count and average
#todo: prettify rules - smooth out >2.5 as >=3 if this is an int, use = if there is only one option

# %% [markdown]
# # Examples

# %% [markdown]
# # Gender Survey

# %%
# https://www.kaggle.com/hb20007/gender-classification
data=pd.read_csv('gender survey.csv')

# %%
data["count"]=1

# %%
X=pd.get_dummies(data,drop_first=True).fillna(0)

# %% [markdown]
# ## Divergence Table

# %%
divergence_table(X,"Gender_M","count",min_count=10)
# Out:
#     Gender_M count  divergence value                               variable
# 7   0.235294    17    0.264706     1               Favorite Music Genre_Pop
# 12  0.642857    14    0.142857     1        Favorite Beverage_Doesn't drink
# 14  0.363636    11    0.136364     1                Favorite Beverage_Other
# 8   0.591837    49    0.091837     0               Favorite Music Genre_Pop
# 2   0.409091    22    0.090909     1                    Favorite Color_Warm
# 21  0.571429    14    0.071429     1              Favorite Soft Drink_Fanta
# 5   0.448276    58    0.051724     0           Favorite Music Genre_Hip hop
# 3   0.545455    44    0.045455     0                    Favorite Color_Warm
# 13  0.461538    52    0.038462     0        Favorite Beverage_Doesn't drink
# 19  0.468750    32    0.031250     1    Favorite Soft Drink_Coca Cola/Pepsi
# 20  0.529412    34    0.029412     0    Favorite Soft Drink_Coca Cola/Pepsi
# 15  0.527273    55    0.027273     0                Favorite Beverage_Other
# 10  0.473684    19    0.026316     1              Favorite Music Genre_Rock
# 23  0.474576    59    0.025424     0              Favorite Soft Drink_Other
# 22  0.480769    52    0.019231     0              Favorite Soft Drink_Fanta
# 18  0.517857    56    0.017857     0                 Favorite Beverage_Wine
# 9   0.483333    60    0.016667     0      Favorite Music Genre_R&B and soul
# 6   0.516129    62    0.016129     0        Favorite Music Genre_Jazz/Blues
# 11  0.510638    47    0.010638     0              Favorite Music Genre_Rock
# 16  0.491228    57    0.008772     0                Favorite Beverage_Vodka
# 17  0.508772    57    0.008772     0              Favorite Beverage_Whiskey
# 1   0.491525    59    0.008475     0                 Favorite Color_Neutral
# 4   0.500000    62    0.000000     0  Favorite Music Genre_Folk/Traditional
# 0   0.500000    66    0.000000     1                                  count

# %% [markdown]
# ## Decision Tree Analyzer

# %%
decision_tree_analyzer(X.drop("Gender_M",axis=1),X.Gender_M,max_depth=5,min_samples_leaf = 20)
# Out:
#    leaf_id         y  count  divergence
# 0        2  0.590909     22    0.090909
#   node_id                              feature sign  threshold
# 0       0                  Favorite Color_Warm   <=        0.5
# 1       1  Favorite Soft Drink_Coca Cola/Pepsi   <=        0.5
#
#    leaf_id         y  count  divergence
# 2        4  0.409091     22    0.090909
#   node_id              feature sign  threshold
# 0       0  Favorite Color_Warm    >        0.5
#
#    leaf_id    y  count  divergence
# 1        3  0.5     22         0.0
#   node_id                              feature sign  threshold
# 0       0                  Favorite Color_Warm   <=        0.5
# 1       1  Favorite Soft Drink_Coca Cola/Pepsi    >        0.5

# %% [markdown]
# # Ames Housing Data

# %%
# https://www.kaggle.com/samaxtech/ames-housing-data
data=pd.read_csv('AmesHousing/AmesHousing.tsv',sep='\t')

# %%
data.shape
# Out:
# (2930, 83)

# %%
data.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'Sale Condition', 'SalePrice'],
#       dtype='object')

# %%
data["count"]=1

# %% [markdown]
# ## Divergence Table

# %%
divergence_table(data,"SalePrice","count",min_count=100)
# Out:
#          SalePrice count     divergence    value         variable
# 93   377918.616822   107  197122.556754       Ex       Exter Qual
# 54   368336.766355   107  187540.706287        9     Overall Qual
# 146  337339.341463   205  156543.281395       Ex     Kitchen Qual
# 101  333369.313953   258  152573.253885       Ex        Bsmt Qual
# 30   322018.265060   166  141222.204992  NridgHt     Neighborhood
# 170  310304.622995   374  129508.562926        3      Garage Cars
# 207  275751.309623   239   94955.249555      New        Sale Type
# 209  273374.371429   245   92578.311360  Partial   Sale Condition
# 55   270913.594286   350   90117.534217        8     Overall Qual
# 107  267507.644366   284   86711.584298       Gd    Bsmt Exposure
# 164  266094.408696   115   85298.348627     2006    Garage Yr Blt
# 65   265924.935780   109   85128.875712     2007       Year Built
# 0     96726.920863   139   84069.139205       30      MS SubClass
# 89   260547.297189   249   79751.237120    Stone     Mas Vnr Type
# 126  101890.479592   196   78905.580476        N      Central Air
# 66   259623.847826   138   78827.787758     2006       Year Built
# 165  259431.043478   115   78634.983410     2007    Garage Yr Blt
# 171  104949.254777   157   75846.805291        0      Garage Cars
# 174  104949.254777   157   75846.805291        0      Garage Area
# 56   106485.097345   226   74310.962723        4     Overall Qual
# 178  107224.236111   216   73571.823957        N      Paved Drive
# 21   253924.525000   120   73128.464932      HLS     Land Contour
# 149  253019.853147   143   72223.793079        9    TotRms AbvGrd
# 161  249344.150538   186   68548.090469  BuiltIn      Garage Type
# 68   115397.343490   361   65398.716578     1950   Year Remod/Add
# 69   244114.500000   164   63318.439932     2007   Year Remod/Add
# 175  117816.822581   124   62979.237488       Fa      Garage Qual
# 156  242316.162896   221   61520.102828        2       Fireplaces
# 67   241993.718310   142   61197.658242     2005       Year Built
# 60   120923.871287   101   59872.188781        4     Overall Cond
# ..             ...   ...            ...      ...              ...
# 106  183847.235092  2616    3051.175023       TA        Bsmt Cond
# 173  183562.102932  1603    2766.042864        2      Garage Cars
# 155  183389.953446  2728    2593.893377      Typ       Functional
# 16   178318.580952   105    2477.479116       75     Lot Frontage
# 199  178364.345865   133    2431.714204        2          Mo Sold
# 184  178434.691099  2674    2361.368969        0     Screen Porch
# 142  183017.339286   112    2221.279217        1    Bedroom AbvGr
# 145  182991.270744  2796    2195.210676        1    Kitchen AbvGr
# 53   178699.875084  1481    2096.184984   1Story      House Style
# 23   178743.737942  2633    2052.322127      Lvl     Land Contour
# 204  178841.750804   622    1954.309264     2008          Yr Sold
# 120  182215.757564  2578    1419.697496        0     BsmtFin SF 2
# 29   179565.365005  2789    1230.695063      Gtl       Land Slope
# 143  179711.767063  1597    1084.293005        3    Bedroom AbvGr
# 205  181761.648000   625     965.587932     2006          Yr Sold
# 189  181751.077821  2827     955.017753        0         Misc Val
# 27   179956.937378   511     839.122691   Corner       Lot Config
# 122  181594.075563  2885     798.015495     GasA          Heating
# 200  181542.562376   505     746.502308        6          Mo Sold
# 135  181536.575009  2753     740.514941        0   Bsmt Half Bath
# 201  180057.063584   173     738.996484       10          Mo Sold
# 76   180114.036024  2887     682.024045  CompShg        Roof Matl
# 206  181404.567901   648     608.507833     2009          Yr Sold
# 131  181327.750865  2890     531.690797        0  Low Qual Fin SF
# 185  180327.043538  2917     469.016530        0        Pool Area
# 17   181100.923920  2918     304.863852     Pave           Street
# 183  180512.847909  2893     283.212160        0       3Ssn Porch
# 45   180615.569310  2900     180.490758     Norm      Condition 2
# 24   180875.412026  2927      79.351958   AllPub        Utilities
# 212  180796.060068  2930       0.000000        1            count
#
# [213 rows x 5 columns]

# %%
X=pd.get_dummies(data,drop_first=True).fillna(0)

# %% [markdown]
# ## Decision Tree Analyzer

# %%
decision_tree_analyzer(X.drop("SalePrice",axis=1),X.SalePrice,max_depth=5,min_samples_leaf = 20)
# Out:
#     leaf_id              y  count     divergence
# 26       52  395179.015625     64  214382.955557
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual    >        7.5
# 2      40    Year Built    >     1998.5
# 3      46    1st Flr SF    >     1684.5
# 4      50  Mas Vnr Area    >      346.0
#
#     leaf_id              y  count     divergence
# 25       51  337405.785714     70  156609.725646
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual    >        7.5
# 2      40    Year Built    >     1998.5
# 3      46    1st Flr SF    >     1684.5
# 4      50  Mas Vnr Area   <=      346.0
#
#     leaf_id              y  count     divergence
# 22       45  329658.823529     34  148862.763461
#   node_id        feature sign  threshold
# 0       0      Full Bath    >        1.5
# 1      28   Overall Qual    >        7.5
# 2      40     Year Built   <=     1998.5
# 3      41  Garage Yr Blt    >     1994.5
#
#     leaf_id              y  count    divergence
# 21       44  321948.148148     27  141152.08808
#   node_id        feature sign  threshold
# 0       0      Full Bath    >        1.5
# 1      28   Overall Qual    >        7.5
# 2      40     Year Built   <=     1998.5
# 3      41  Garage Yr Blt   <=     1994.5
# 4      42   Lot Frontage    >       74.0
#
#     leaf_id              y  count     divergence
# 24       49  289066.820513    117  108270.760445
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual    >        7.5
# 2      40    Year Built    >     1998.5
# 3      46    1st Flr SF   <=     1684.5
# 4      47  BsmtFin SF 1    >       50.0
#
#    leaf_id             y  count    divergence
# 0        5  82701.745283    106  98094.314785
#   node_id       feature sign  threshold
# 0       0     Full Bath   <=        1.5
# 1       1    1st Flr SF   <=     1047.5
# 2       2  BsmtFin SF 1   <=      348.5
# 3       3  Overall Qual   <=        4.5
# 4       4   Bsmt Unf SF   <=      722.0
#
#     leaf_id              y  count    divergence
# 19       39  277532.222222     27  96736.162154
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual   <=        7.5
# 2      29    Year Built    >     1978.5
# 3      35   Gr Liv Area    >     2336.5
#
#    leaf_id             y  count    divergence
# 1        6  96154.969697     33  84641.090371
#   node_id       feature sign  threshold
# 0       0     Full Bath   <=        1.5
# 1       1    1st Flr SF   <=     1047.5
# 2       2  BsmtFin SF 1   <=      348.5
# 3       3  Overall Qual   <=        4.5
# 4       4   Bsmt Unf SF    >      722.0
#
#     leaf_id              y  count    divergence
# 23       48  258931.039216    102  78134.979147
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual    >        7.5
# 2      40    Year Built    >     1998.5
# 3      46    1st Flr SF   <=     1684.5
# 4      47  BsmtFin SF 1   <=       50.0
#
#     leaf_id           y  count    divergence
# 20       43  252890.625     32  72094.564932
#   node_id        feature sign  threshold
# 0       0      Full Bath    >        1.5
# 1      28   Overall Qual    >        7.5
# 2      40     Year Built   <=     1998.5
# 3      41  Garage Yr Blt   <=     1994.5
# 4      42   Lot Frontage   <=       74.0
#
#    leaf_id             y  count    divergence
# 4       12  113822.44898     49  66973.611089
#   node_id        feature sign  threshold
# 0       0      Full Bath   <=        1.5
# 1       1     1st Flr SF   <=     1047.5
# 2       2   BsmtFin SF 1    >      348.5
# 3      10    Garage Area   <=      287.0
# 4      11  Garage Yr Blt   <=     1941.5
#
#    leaf_id              y  count    divergence
# 2        8  115924.462857    175  64871.597211
#   node_id       feature sign  threshold
# 0       0     Full Bath   <=        1.5
# 1       1    1st Flr SF   <=     1047.5
# 2       2  BsmtFin SF 1   <=      348.5
# 3       3  Overall Qual    >        4.5
# 4       7  Overall Cond   <=        6.5
#
#    leaf_id              y  count    divergence
# 5       13  122137.333333     54  58658.726735
#   node_id        feature sign  threshold
# 0       0      Full Bath   <=        1.5
# 1       1     1st Flr SF   <=     1047.5
# 2       2   BsmtFin SF 1    >      348.5
# 3      10    Garage Area   <=      287.0
# 4      11  Garage Yr Blt    >     1941.5
#
#    leaf_id          y  count    divergence
# 7       16  126868.95     40  53927.110068
#   node_id             feature sign  threshold
# 0       0           Full Bath   <=        1.5
# 1       1          1st Flr SF   <=     1047.5
# 2       2        BsmtFin SF 1    >      348.5
# 3      10         Garage Area    >      287.0
# 4      14  BsmtFin Type 1_Rec    >        0.5
#
#    leaf_id              y  count    divergence
# 3        9  129334.526667    150  51461.533402
#   node_id       feature sign  threshold
# 0       0     Full Bath   <=        1.5
# 1       1    1st Flr SF   <=     1047.5
# 2       2  BsmtFin SF 1   <=      348.5
# 3       3  Overall Qual    >        4.5
# 4       7  Overall Cond    >        6.5
#
#    leaf_id              y  count    divergence
# 8       20  137396.309091    220  43399.750977
#   node_id        feature sign  threshold
# 0       0      Full Bath   <=        1.5
# 1       1     1st Flr SF    >     1047.5
# 2      17  Total Bsmt SF   <=     1225.0
# 3      18   Mas Vnr Area   <=      268.0
# 4      19     Year Built   <=     1963.5
#
#    leaf_id              y  count    divergence
# 6       15  138015.966981    212  42780.093087
#   node_id             feature sign  threshold
# 0       0           Full Bath   <=        1.5
# 1       1          1st Flr SF   <=     1047.5
# 2       2        BsmtFin SF 1    >      348.5
# 3      10         Garage Area    >      287.0
# 4      14  BsmtFin Type 1_Rec   <=        0.5
#
#     leaf_id              y  count    divergence
# 14       32  149055.224932    369  31740.835136
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual   <=        7.5
# 2      29    Year Built   <=     1978.5
# 3      30  Screen Porch   <=      198.5
# 4      31      Lot Area   <=    13625.0
#
#    leaf_id             y  count    divergence
# 9       21  150420.07438    121  30375.985688
#   node_id        feature sign  threshold
# 0       0      Full Bath   <=        1.5
# 1       1     1st Flr SF    >     1047.5
# 2      17  Total Bsmt SF   <=     1225.0
# 3      18   Mas Vnr Area   <=      268.0
# 4      19     Year Built    >     1963.5
#
#     leaf_id              y  count    divergence
# 15       33  210619.488372     86  29823.428304
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual   <=        7.5
# 2      29    Year Built   <=     1978.5
# 3      30  Screen Porch   <=      198.5
# 4      31      Lot Area    >    13625.0
#
#     leaf_id              y  count   divergence
# 12       26  208102.616438     73  27306.55637
#   node_id        feature sign  threshold
# 0       0      Full Bath   <=        1.5
# 1       1     1st Flr SF    >     1047.5
# 2      17  Total Bsmt SF    >     1225.0
# 3      23          Order   <=     2257.5
# 4      24          Order    >      784.5
#
#     leaf_id              y  count    divergence
# 18       38  203263.837786    524  22467.777718
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual   <=        7.5
# 2      29    Year Built    >     1978.5
# 3      35   Gr Liv Area   <=     2336.5
# 4      36    1st Flr SF    >      794.5
#
#     leaf_id              y  count    divergence
# 10       22  160156.583333     24  20639.476735
#   node_id        feature sign  threshold
# 0       0      Full Bath   <=        1.5
# 1       1     1st Flr SF    >     1047.5
# 2      17  Total Bsmt SF   <=     1225.0
# 3      18   Mas Vnr Area    >      268.0
#
#     leaf_id              y  count   divergence
# 13       27  196059.103448     29  15263.04338
#   node_id        feature sign  threshold
# 0       0      Full Bath   <=        1.5
# 1       1     1st Flr SF    >     1047.5
# 2      17  Total Bsmt SF    >     1225.0
# 3      23          Order    >     2257.5
#
#     leaf_id              y  count    divergence
# 16       34  193316.666667     24  12520.606598
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual   <=        7.5
# 2      29    Year Built   <=     1978.5
# 3      30  Screen Porch    >      198.5
#
#     leaf_id              y  count  divergence
# 17       37  171949.032258    124  8847.02781
#   node_id       feature sign  threshold
# 0       0     Full Bath    >        1.5
# 1      28  Overall Qual   <=        7.5
# 2      29    Year Built    >     1978.5
# 3      35   Gr Liv Area   <=     2336.5
# 4      36    1st Flr SF   <=      794.5
#
#     leaf_id              y  count   divergence
# 11       25  187169.477273     44  6373.417204
#   node_id        feature sign  threshold
# 0       0      Full Bath   <=        1.5
# 1       1     1st Flr SF    >     1047.5
# 2      17  Total Bsmt SF    >     1225.0
# 3      23          Order   <=     2257.5
# 4      24          Order   <=      784.5

# %% [markdown]
# ## Decision Tree Analyzer For Remainders of Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X.drop("SalePrice",axis=1),data.SalePrice)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = lr.predict(X.drop("SalePrice",axis=1))
y_error = data.SalePrice-y_pred

# %%
decision_tree_analyzer(X.drop("SalePrice",axis=1),y_error,max_depth=5,min_samples_leaf = 20)
# Out:
#     leaf_id             y  count    divergence
# 11       23  47637.164789     34  47637.164789
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF    >     1924.0
# 1      20        Mo Sold   <=        7.5
# 2      21    Garage Area    >      739.0
#
#    leaf_id             y  count    divergence
# 9       19  29182.563646     21  29182.563646
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF   <=     1924.0
# 1       1    Garage Area    >      434.5
# 2      11      Full Bath    >        2.5
# 3      17  Total Bsmt SF    >     1268.5
#
#    leaf_id             y  count    divergence
# 2        7  16382.579543     26  16382.579543
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF   <=     1924.0
# 1       1    Garage Area   <=      434.5
# 2       2          Order    >       88.5
# 3       4   Overall Qual   <=        3.5
# 4       5       Lot Area    >     8121.0
#
#     leaf_id             y  count    divergence
# 12       24 -15060.067835     25  15060.067835
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF    >     1924.0
# 1      20        Mo Sold    >        7.5
#
#    leaf_id             y  count    divergence
# 7       16 -13884.596158     36  13884.596158
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF   <=     1924.0
# 1       1    Garage Area    >      434.5
# 2      11      Full Bath   <=        2.5
# 3      12       Lot Area    >    24246.0
#
#    leaf_id             y  count    divergence
# 0        3  13765.190489     23  13765.190489
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF   <=     1924.0
# 1       1    Garage Area   <=      434.5
# 2       2          Order   <=       88.5
#
#    leaf_id             y  count    divergence
# 5       14 -11094.386853     65  11094.386853
#   node_id        feature sign    threshold
# 0       0  Total Bsmt SF   <=       1924.0
# 1       1    Garage Area    >        434.5
# 2      11      Full Bath   <=          2.5
# 3      12       Lot Area   <=      24246.0
# 4      13            PID   <=  527214016.0
#
#    leaf_id            y  count   divergence
# 3        9  5466.881261    164  5466.881261
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF   <=     1924.0
# 1       1    Garage Area   <=      434.5
# 2       2          Order    >       88.5
# 3       4   Overall Qual    >        3.5
# 4       8   Lot Frontage   <=       10.5
#
#     leaf_id            y  count   divergence
# 10       22  4766.173673     21  4766.173673
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF    >     1924.0
# 1      20        Mo Sold   <=        7.5
# 2      21    Garage Area   <=      739.0
#
#    leaf_id            y  count   divergence
# 8       18 -4192.190137     31  4192.190137
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF   <=     1924.0
# 1       1    Garage Area    >      434.5
# 2      11      Full Bath    >        2.5
# 3      17  Total Bsmt SF   <=     1268.5
#
#    leaf_id            y  count   divergence
# 1        6  2307.112939     22  2307.112939
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF   <=     1924.0
# 1       1    Garage Area   <=      434.5
# 2       2          Order    >       88.5
# 3       4   Overall Qual   <=        3.5
# 4       5       Lot Area   <=     8121.0
#
#    leaf_id            y  count   divergence
# 6       15 -1666.882671   1548  1666.882671
#   node_id        feature sign    threshold
# 0       0  Total Bsmt SF   <=       1924.0
# 1       1    Garage Area    >        434.5
# 2      11      Full Bath   <=          2.5
# 3      12       Lot Area   <=      24246.0
# 4      13            PID    >  527214016.0
#
#    leaf_id           y  count  divergence
# 4       10  312.161952    914  312.161952
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF   <=     1924.0
# 1       1    Garage Area   <=      434.5
# 2       2          Order    >       88.5
# 3       4   Overall Qual    >        3.5
# 4       8   Lot Frontage    >       10.5

# %% [markdown]
# ## Decision Analyzer 2: Gives the most divergent leaf of every tree up to X deep

# %%
decision_tree_analyzer2(X.drop("SalePrice",axis=1),y_error,deepest=5,min_samples_leaf = 20)
# Out:
#    leaf_id             y  count    divergence
# 1        2  16790.644426     80  16790.644426
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF    >     1924.0
#
#    leaf_id             y  count    divergence
# 2        5  31268.240908     55  31268.240908
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF    >     1924.0
# 1       4        Mo Sold   <=        7.5
#
#    leaf_id             y  count    divergence
# 5       11  47637.164789     34  47637.164789
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF    >     1924.0
# 1       8        Mo Sold   <=        7.5
# 2       9    Garage Area    >      739.0
#
#    leaf_id             y  count    divergence
# 8       17  47637.164789     34  47637.164789
#   node_id        feature sign  threshold
# 0       0  Total Bsmt SF    >     1924.0
# 1      14        Mo Sold   <=        7.5
# 2      15    Garage Area    >      739.0

# %% [markdown]
# ## Boston Housing Data

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
boston = load_boston()
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(boston.data, boston.target)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
X=pd.DataFrame(boston.data)
decision_tree_analyzer(X,boston.target,max_depth=5,min_samples_leaf = 10)
# Out:
#     leaf_id       y  count  divergence
# 18       37  47.975     16   25.442194
#   node_id feature sign  threshold
# 0       0       5    >      6.941
# 1      28       5    >      7.437
# 2      36      10   <=     15.400
#
#     leaf_id          y  count  divergence
# 19       38  41.807143     14   19.274337
#   node_id feature sign  threshold
# 0       0       5    >      6.941
# 1      28       5    >      7.437
# 2      36      10    >     15.400
#
#     leaf_id      y  count  divergence
# 14       31  37.19     10   14.657194
#   node_id feature sign  threshold
# 0       0       5    >     6.9410
# 1      28       5   <=     7.4370
# 2      29      12   <=     5.4950
# 3      30       7   <=     5.3229
#
#     leaf_id        y  count  divergence
# 13       27  9.81087     46   12.721937
#   node_id feature sign  threshold
# 0       0       5   <=      6.941
# 1       1      12    >     14.400
# 2      13       4    >      0.607
# 3      21      12    >     19.645
# 4      25       9    >    551.500
#
#    leaf_id      y  count  divergence
# 1        5  34.47     10   11.937194
#   node_id feature sign  threshold
# 0       0       5   <=    6.94100
# 1       1      12   <=   14.40000
# 2       2      12   <=    4.91000
# 3       3       4    >    0.43995
#
#     leaf_id          y  count  divergence
# 15       32  33.753846     13    11.22104
#   node_id feature sign  threshold
# 0       0       5    >     6.9410
# 1      28       5   <=     7.4370
# 2      29      12   <=     5.4950
# 3      30       7    >     5.3229
#
#     leaf_id     y  count  divergence
# 17       35  33.4     12   10.867194
#   node_id feature sign  threshold
# 0       0       5    >      6.941
# 1      28       5   <=      7.437
# 2      29      12    >      5.495
# 3      33       1    >      8.750
#
#    leaf_id      y  count  divergence
# 3        9  31.17     10    8.637194
#   node_id feature sign  threshold
# 0       0       5   <=   6.941000
# 1       1      12   <=  14.400000
# 2       2      12    >   4.910000
# 3       6      12   <=   9.715000
# 4       7       6    >  87.600006
#
#     leaf_id          y  count  divergence
# 11       24  14.195652     23    8.337154
#   node_id feature sign  threshold
# 0       0       5   <=    6.94100
# 1       1      12    >   14.40000
# 2      13       4    >    0.60700
# 3      21      12   <=   19.64500
# 4      22       0    >    5.76921
#
#     leaf_id      y  count  divergence
# 12       26  14.41     10    8.122806
#   node_id feature sign  threshold
# 0       0       5   <=      6.941
# 1       1      12    >     14.400
# 2      13       4    >      0.607
# 3      21      12    >     19.645
# 4      25       9   <=    551.500
#
#    leaf_id          y  count  divergence
# 8       19  14.516667     12     8.01614
#   node_id feature sign  threshold
# 0       0       5   <=    6.94100
# 1       1      12    >   14.40000
# 2      13       4   <=    0.60700
# 3      14       0    >    0.55381
# 4      18       8   <=    4.50000
#
#    leaf_id      y  count  divergence
# 0        4  28.66     10    6.127194
#   node_id feature sign  threshold
# 0       0       5   <=    6.94100
# 1       1      12   <=   14.40000
# 2       2      12   <=    4.91000
# 3       3       4   <=    0.43995
#
#     leaf_id          y  count  divergence
# 10       23  16.535714     28    5.997092
#   node_id feature sign  threshold
# 0       0       5   <=    6.94100
# 1       1      12    >   14.40000
# 2      13       4    >    0.60700
# 3      21      12   <=   19.64500
# 4      22       0   <=    5.76921
#
#    leaf_id          y  count  divergence
# 9       20  16.964706     17      5.5681
#   node_id feature sign  threshold
# 0       0       5   <=    6.94100
# 1       1      12    >   14.40000
# 2      13       4   <=    0.60700
# 3      14       0    >    0.55381
# 4      18       8    >    4.50000
#
#    leaf_id          y  count  divergence
# 7       17  19.066667     27     3.46614
#   node_id feature sign  threshold
# 0       0       5   <=   6.941000
# 1       1      12    >  14.400000
# 2      13       4   <=   0.607000
# 3      14       0   <=   0.553810
# 4      15       0    >   0.147465
#
#    leaf_id         y  count  divergence
# 5       12  20.31875     80    2.214056
#   node_id feature sign  threshold
# 0       0       5   <=   6.941000
# 1       1      12   <=  14.400000
# 2       2      12    >   4.910000
# 3       6      12    >   9.715000
# 4      10      10    >  17.849998
#
#     leaf_id          y  count  divergence
# 16       34  24.154545     11    1.621739
#   node_id feature sign  threshold
# 0       0       5    >      6.941
# 1      28       5   <=      7.437
# 2      29      12    >      5.495
# 3      33       1   <=      8.750
#
#    leaf_id      y  count  divergence
# 6       16  21.25     12    1.282806
#   node_id feature sign  threshold
# 0       0       5   <=   6.941000
# 1       1      12    >  14.400000
# 2      13       4   <=   0.607000
# 3      14       0   <=   0.553810
# 4      15       0   <=   0.147465
#
#    leaf_id        y  count  divergence
# 2        8  23.7875    112    1.254694
#   node_id feature sign  threshold
# 0       0       5   <=   6.941000
# 1       1      12   <=  14.400000
# 2       2      12    >   4.910000
# 3       6      12   <=   9.715000
# 4       7       6   <=  87.600006
#
#    leaf_id          y  count  divergence
# 4       11  21.863636     33     0.66917
#   node_id feature sign  threshold
# 0       0       5   <=   6.941000
# 1       1      12   <=  14.400000
# 2       2      12    >   4.910000
# 3       6      12    >   9.715000
# 4      10      10   <=  17.849998
